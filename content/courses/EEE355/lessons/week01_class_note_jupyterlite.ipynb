# %% [markdown]
# # EEE355 — Computation Structures
# ## Week 1: Introduction to Computation and Digital Abstraction
#
# **Lesson Type:** JupyterLite Interactive Class Note

# %% [markdown]
# ## Teacher Setup
#
# Before class, fill in `API_BASE`, `ASSESSMENT_ID`, `ATTENDANCE_SESSION_ID`, `LESSON_SLUG`, and `QUESTION_1_ID`.

# %%
import os, sys
sys.path.append(os.path.abspath("../_shared"))
from classlite_jupyter import ClassLiteConfig, ClassLiteNotebookApp

config = ClassLiteConfig(
    api_base="http://localhost:8000",
    assessment_id=1,
    attendance_session_id=1,
    lesson_slug="week01_intro",
    question_ids={"question_1": 1},
)
app = ClassLiteNotebookApp(config)

# %% [markdown]
# ## Student Login

# %%
app.render_login_widget()

# %% [markdown]
# ## Start / Resume Lesson Quiz

# %%
app.render_attempt_controls()

# %% [markdown]
# ## Main Note Content
#
# ### What is Computation?
#
# Computation is the process of transforming information according to rules.

# %% [markdown]
# ## Digital Abstraction
#
# Digital abstraction means representing information using discrete values instead of continuous ones.

# %%
def analog_to_digital_example(value, threshold=0.5):
    return 1 if value >= threshold else 0

samples = [0.1, 0.3, 0.49, 0.5, 0.7, 0.95]
[(x, analog_to_digital_example(x)) for x in samples]

# %% [markdown]
# ## Quick Check Question

# %%
app.render_mcq_single(
    question_id=config.question_ids["question_1"],
    prompt="Q1. Which of the following best describes digital abstraction?",
    options=[
        ("a", "Representation using continuous values only"),
        ("b", "Representation using discrete values"),
        ("c", "Elimination of all physical signals"),
        ("d", "Use of decimal numbers only"),
    ],
)

# %% [markdown]
# ## Attendance Check

# %%
app.render_attendance_widget()

# %% [markdown]
# ## Autosave, Scores, and Submit

# %%
app.render_submit_controls()
