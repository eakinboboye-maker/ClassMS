# %% [markdown]
# # EEE355 Attendance Check-In

# %%
import os, sys
sys.path.append(os.path.abspath("../_shared"))
from classlite_jupyter import ClassLiteConfig, ClassLiteNotebookApp

config = ClassLiteConfig(api_base="http://localhost:8000", assessment_id=1, attendance_session_id=1, lesson_slug="attendance_only")
app = ClassLiteNotebookApp(config)

# %% [markdown]
# ## Login

# %%
app.render_login_widget()

# %% [markdown]
# ## Mark Attendance

# %%
app.render_attendance_widget()
