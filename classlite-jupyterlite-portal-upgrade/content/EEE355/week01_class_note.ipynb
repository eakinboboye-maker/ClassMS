# %% [markdown]
# # EEE355 — Computation Structures
# ## Week 1 Class Note
#
# The portal now handles login, lesson access, attendance, and performance. This notebook is for the lesson content and notebook quiz only.

# %%
from _shared.classlite_site_config import API_BASE
from _shared.classlite_jupyter import ClassLiteLesson
from _shared.classlite_quiz_ui import QuizNotebookUI

LESSON_SLUG = "week01_intro"
lesson = ClassLiteLesson(api_base=API_BASE, lesson_slug=LESSON_SLUG)
lesson.bootstrap_from_portal()

# %% [markdown]
# ## Lesson Content
#
# Computation transforms information according to rules.
#
# Digital abstraction represents information using discrete states such as 0/1, TRUE/FALSE, or ON/OFF.

# %%
def analog_to_digital_example(value, threshold=0.5):
    return 1 if value >= threshold else 0

samples = [0.1, 0.3, 0.49, 0.5, 0.7, 0.95]
[(x, analog_to_digital_example(x)) for x in samples]

# %% [markdown]
# ## Notebook Quiz

# %%
lesson.start_attempt()
paper = lesson.fetch_paper()
ui = QuizNotebookUI(lesson, paper["items"])
ui.render()
