# %% [markdown]
# # EEE355 — Computation Structures
# ## Week 1: Xeus-based class note
#
# This version is corrected for the **Xeus Python** kernel.
# It uses a login widget with hidden password input and synchronous backend calls.

# %%
from _shared.classlite_jupyter import ClassLiteLesson

API_BASE = "http://localhost:8000"
ASSESSMENT_ID = 1
ATTENDANCE_SESSION_ID = 1
LESSON_SLUG = "week01_intro"
QUESTION_1_ID = 1

lesson = ClassLiteLesson(
    api_base=API_BASE,
    assessment_id=ASSESSMENT_ID,
    attendance_session_id=ATTENDANCE_SESSION_ID,
    lesson_slug=LESSON_SLUG,
)

# %% [markdown]
# ## Student Login
#
# Run the next cell and log in with your email and password.

# %%
lesson.login_widget()

# %% [markdown]
# ## Main note
#
# Digital abstraction means representing information using **discrete values**.

# %%
def analog_to_digital_example(value, threshold=0.5):
    return 1 if value >= threshold else 0

samples = [0.1, 0.3, 0.49, 0.5, 0.7, 0.95]
[(x, analog_to_digital_example(x)) for x in samples]

# %% [markdown]
# ## Start backend lesson attempt

# %%
lesson.start_attempt()

# %%
lesson.fetch_paper()

# %% [markdown]
# ## Quick Check
#
# Q1. Which of the following best describes digital abstraction?
#
# a. Representation using continuous values only
# b. Representation using discrete values
# c. Elimination of all physical signals
# d. Use of decimal numbers only

# %%
lesson.answer_mcq(QUESTION_1_ID, "b")

# %%
lesson.autosave()

# %% [markdown]
# ## Attendance

# %%
lesson.mark_attendance()

# %% [markdown]
# ## Submit

# %%
lesson.submit()

# %% [markdown]
# ## Score Summary

# %%
lesson.scores()
