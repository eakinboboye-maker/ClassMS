// %% [markdown]
// ## Basic Operations with C- Arithmetic and Logicals
//
// Most programming languages share a math-like syntax when doing basic calculator operations, and C and C++ (which builds extra features onto the C language) are no exception!  Of course, there can be some surprises when using a new tool.
//
// | Code | Description |
// | :-- | :-- |
// | `1 + 2 * 3 / 5`  |  Arithmetic Operators |
// | `10 % 3`  | Remainder after Integer Division Operator  |
// | `(3 > 5) == (2 <= 5) != (6 >= 4)`  |  Comparison Operators |
// | `12` | `int` (integer) |
// | `12.0`  | `double` decimal value (needed for decimal math)|
// | `true` | `bool` logical value |
//
// #### **Exercises**

// %% [markdown]
// Let's play around a bit with some math to get a feel for it!  In each exercise, fill in the requested code below.  If you're stuck, use the table above to find helpful code.

// %% [markdown]
// **Example**: What is one plus one?

// %%
1 + 1
// Out:
// 2

// %% [markdown]
// **Exercise**: What is three plus five?

// %%
3 + 5
// Out:
// 8

// %% [markdown]
//  **Exercise**: What is six times eight?

// %%
6 * 8
// Out:
// 48

// %% [markdown]
//  **Exercise**: What is 12 divided by 4?

// %%
12 / 4
// Out:
// 3

// %% [markdown]
//  **Exercise**: What is 9 divided by 5?

// %%
9 / 5.0
// Out:
// 1.8000000

// %% [markdown]
//  **Exercise**: How many whole times does 20 go into 3?  (in other words, integer division 20 divided by 3)

// %%
20 / 3
// Out:
// 6

// %% [markdown]
//  **Exercise**: What is the remainder after dividing 20 by 3?

// %%
20 % 3
// Out:
// 2

// %% [markdown]
// **Exercise**:  What is `4 + 5 * 2`?  Does C++ follow the right order of operations?

// %%
4 + 5 * 2
// Out:
// 14

// %% [markdown]
//  **Exercise**: Is `0.1 + 0.2 - 0.3` equal to zero?

// %%
(0.1 + 0.2 - 0.3) == 0
// Out:
// false

// %% [markdown]
//  **Exercise**: Is `0.1f + 0.2f - 0.3f` equal to zero?

// %%
(0.1f + 0.2f - 0.3f) == 0
// Out:
// true

// %% [markdown]
//  **Exercise**: Is four times six greater than three times seven?

// %%
4 * 6 > 3 * 7
// Out:
// true

// %% [markdown]
//  **Exercise**: Is `true` equal to `1` in C++?

// %%
true == 1
// Out:
// true

// %% [markdown]
//  **Exercise**: Is `false` equal to `0` in C++?

// %%
false == 0
// Out:
// true

// %% [markdown]
// ## Coding with Static Types- Identifiers (a.k.a. "Variables")
//
// We didn't create any variables last time; that's because C and C++ require that the `type` of the identifier (the name of the variable) be specified.
// This extra bit of code helps the compiler make the code extremely efficient, as it takes a lot of guesswork out of the equation.
// It also gives the programmer a lot of creative freedom to decide how the computer should manage its resources, which is useful when you have lots of data to process (like in data analysis), or
// have little computing power to work with (like in Arduino microprocessors).
//
// | Code | Description |
// | :-- | :-- |
// | `int x;` | "Make a new identifier called `x`, which references an integer in memory." |
// | `x = 42;` | "Store 42 at where the (previously-created) identifier `x` is stored." |
// | `int x = 42;` | "Make a new identifier called x, which references an integer in memory, **and** store 42 there." |
// | `short x = 10` | b  |
//
// #### **Exercises**

// %% [markdown]
// **Example**: Set `x` to the value `3`, and `y` to `x` plus `5`.  Encode both as `int`.  Print the value of y.

// %%
int x = 3;
int y = x + 5;
y
// Out:
// 8

// %% [markdown]
//  **Exercise**: What if `y` was encoded as a `double`?  Would it change what was printed?

// %%
int x = 3;
double y = x + 5;
y
// Out:
// 8.0000000

// %% [markdown]
//  **Exercise**: What if `y` was encoded as a `float`?

// %%
int x = 3;
float y = x + 5;
y
// Out:
// 8.00000f

// %% [markdown]
//  **Exercise**: What if `y` was encoded as a `char`?

// %%
int x = 3;
char y = x + 5;
y
// Out:
// '0x08'

// %% [markdown]
// Different types require different amounts of memory; the more memory a type uses, the greater the range of values it can store.  Reference the two tables at https://en.cppreference.com/w/cpp/language/types to create integers stored in different ways:

// %% [markdown]
// ---

// %% [markdown]
// **Example** Create `num`, an integer that takes up only 16 bits, and is `signed` (it can store both positive and negative numbers).

// %%
short num;
num
// Out:
// 0

// %% [markdown]
// **Example**: Set the value of `num` to 1000 (without changing its type).  Does it store it properly?

// %%
num = 1000;
num
// Out:
// 1000

// %% [markdown]
//  **Exercise**: Set the value of `num` to negative 1000.  Does it store it properly?

// %%
num = -1000;
num
// Out:
// -1000

// %% [markdown]
//  **Exercise**: Set the value of num to a million.  Does it store properly?

// %%
num = 1000000;
num
// Out:
// input_line_49:2:8: warning: implicit conversion from 'int' to 'short' changes value from 1000000 to 16960 [-Wconstant-conversion]
//  num = 1000000;
//      ~ ^~~~~~~
// 16960

// %% [markdown]
// **Exercise**: Now, instead of explicitly setting the value to 1 milliion, this time simply add one million to `num`.  Does it store the number correctly?  What's different about what happens?

// %%
num = num + 100000;
num
// Out:
// -14112

// %% [markdown]
// ---

// %% [markdown]
// The code below creates `temp_k`, a temperature stored in Kelvin, which means there should never be negative values.  This time, let's store it using the most memory we can: something with at least 64 bits of memory.  (See the table here to find a good candidate: https://en.cppreference.com/w/cpp/language/types)

// %%
unsigned long long int temp_k;
temp_k
// Out:
// 0

// %% [markdown]
// **Exercise**: Set `temp_k` to the highest value you can without getting an error.

// %%
temp_k = 999999999999999999;
temp_k
// Out:
// 999999999999999999

// %% [markdown]
// **Exercise**: Check that `temp_k` is only for positive values, by trying to set `temp_k` to negative one. What value is temp_k?

// %%
temp_k = -1;
temp_k
// Out:
// 18446744073709551615

// %% [markdown]
// **Exercise**: Can we store text as an integer?  Try storing the string `"hello!"` in `temp_k`.

// %%
temp_k = "Hello!";
temp_k

// %% [markdown]
// ---

// %% [markdown]
//  **Exercise**: Create `brightness`, an image pixel value that stores a value between 0-255. That's 256 values in total that the pixel could be set at.  Since 256 is $2^8$, let's store it in one of the integer types in (https://en.cppreference.com/w/cpp/language/types) only using 8 bits.

// %%
unsigned char brightness;
brightness
// Out:
// '0x00'

// %% [markdown]
// **Exercise**: Store the number 66 in `brightness`.  What's weird about how the number is printed?  (Note: the reason for this is because 8-bit integers are also used to store [ASCII text data](https://en.wikipedia.org/wiki/ASCII). To tell C++ that it can be "elevated" in its representation to a number, put a plus sign before the variable when printing it: (`e.g. +brightness`).

// %%
brightness = 66;
+brightness
// Out:
// 66

// %% [markdown]
// ---

// %% [markdown]
// ## Introduction to C++ Arrays
//
//
// | Code | Description |
// | :-- | :-- |
// | `char myString[10] = "Hello";` | Store the characters 'Hello' in a char array of fixed-length of 10. In C, this is essentially a String. |
// | `int myNums[5] = {1, 2, 3, 4, 5};` | Store the integers 1-5 in an array. |
// | `myNums[2] = 33;` | Put the value 33 in the third index of the `myNums` array. |
//
// #### **Exercises**

// %% [markdown]
// **Example**: Put the numbers 10, 20, and 30 into an array of length 3 called `cc`.  How does it look when printed?

// %%
int cc[3] = {10, 20, 30};
cc
// Out:
// { 10, 20, 30 }

// %% [markdown]
// **Exercise**: Put the numbers 1, 2, and 3 into an array of length 10 called `nums`. How does it look when printed

// %%
int nums[10] = {1, 2, 3};
nums
// Out:
// { 1, 2, 3, 0, 0, 0, 0, 0, 0, 0 }

// %% [markdown]
//  **Exercise**: Replace the fifth value in `nums` with 555.  Did it work?

// %%
nums[4] = 555;
nums
// Out:
// { 1, 2, 3, 0, 555, 0, 0, 0, 0, 0 }

// %% [markdown]
//  **Exercise**: Put the character `'i'` in the 6th position in `nums`.  Did it work?

// %%
nums[6] = 'i';
nums
// Out:
// { 1, 2, 3, 0, 555, 0, 105, 0, 0, 0 }

// %% [markdown]
//  **Exercise**: Make a new array called `small`, that contains only 8 boolean values. Don't initialize it with any values.  What's the default?

// %%
bool small[8];
small
// Out:
// { false, false, false, false, false, false, false, false }

// %% [markdown]
//  **Exercise**: Use the `sizeof()` function.  How many big is the `small` array?

// %%
sizeof(small)
// Out:
// 8

// %% [markdown]
//  **Exercise**: Use the `sizeof()` function. How big is the `nums` array?  Is this what was expected? What does this mean about what `sizeof()` is calculating?

// %%
sizeof(nums)
// Out:
// 40

// %% [markdown]
//  **Exercise**: Make an array of integers called `birthday` that stores the year, month, and day of your birthday.  Make it have the smallest `sizeof()` measurement you can, while still storing the data correctly.

// %%
short birthday[3] = {1992,5,8};
sizeof(birthday)
// Out:
// 6

// %% [markdown]
//  **Exercise**: Declare an array of `chars` called `myName` and initialize it with your name.

// %%
char myName[5] = "Nick";
myName
// Out:
// "Nick"

// %% [markdown]
//  **Exercise**: Change the first character of the string to 'A'.

// %%
myName[0] = 'A';
myName
// Out:
// "Aick"

// %% [markdown]
//  **Exercise**: Change the last character of the string to 'Z'

// %%
myName[4] = 'Z';
myName
// Out:
// "AickZ"

// %% [markdown]
//  **Exercise**: Replace your name entirely with your last name. (Note that this doesn't work the same way as with numbers; the `strcpy(old, new)` function is useful for this).

// %%
strcpy(myName, "Josephina");
myName
// Out:
// "Josep"

// %% [markdown]
// ## Structures and Structure Arrays
//
// Great code is self-documented, and the simplest way to compress your data into small packets and make your code readable at the same time is the handy `struct`!
//
// | Code | Description |
// | :-- | :-- |
// | `struct MyStruct {int a; short b; unsigned char c;}` |  Creates a structure called `MyStruct` with three named variables |
// | `struct MyStruct x = {1, 2, 3}` | Puts data into the structure. |
// | `x.a` | Gets the data from the `a` variable in the structure |
//
// #### **Exercises**

// %% [markdown]
//  **Exercise**: Make a `Birthday` struct containing the year, month, and day of a birthday.

// %%
struct Birthday {int year; int month; int day;}
Birthday

// %% [markdown]
//  **Exercise**: Store a birthday into a `Birthday` struct, called `bday`.  Note that printing this will be tricky, you'll get an error.

// %%
struct Birthday bday = {2022, 7, 23};

// %% [markdown]
//  **Exercise**: Access the `month` field from `bday`.  Is it correct?

// %%
+bday.month
// Out:
// 7

// %% [markdown]
//  **Exercise**: Access the `day` field from `bday1`. Is it correct?

// %%
+bday.day
// Out:
// 23

// %% [markdown]
//  **Exercise**: How many bytes does `bday1` take up?

// %%
sizeof(bday)
// Out:
// 12

// %% [markdown]
//  **Exercise**: Make a the `Birthday2` struct so that it takes up as little possible space to store the information accurately.  Could you get it smaller than the array you used before?

// %%
struct Birthday2 {ushort year; unsigned char month; unsigned char day;};
struct Birthday2 bday2 = {2022, 7, 23};
sizeof(bday2)
// Out:
// 4

// %% [markdown]
//  **Exercise**: Make an array of structs containing three birthdays, called `bdays`.  Fill the array with the three birthdays' data.

// %%
struct Birthday2 bdays[3];
bdays[0] = {1988, 1, 15};
bdays[1] = {2222, 3, 2};
bdays[2] = {3333, 11, 12};

// %% [markdown]
//  **Exercise**: Print the month of the first birthday in `bdays`:

// %%
bdays[0].month
// Out:
// '0x01'

// %% [markdown]
//  **Exercise**: Print the day of the second birthday in `bdays`

// %%
bdays[1].day
// Out:
// '0x02'

// %% [markdown]
//  **Exercise**: Print the year of the third birthday in `bdays`

// %%
bdays[2].year
// Out:
// 3333

// %% [markdown]
//  **Exercise**: How many bytes does `bdays` take up?

// %%
sizeof(bdays)
// Out:
// 12
